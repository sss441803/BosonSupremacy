# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
d = 4
dd = 6
id = 0
chi = 800
rootdir = '/project2/liangjiang/mliu6/DirectMPS/data_3a/'
filename = rootdir + f"samples_d_{d}_dd_{dd}_chi_{chi}_{id}.npy"
samples = np.load(filename)
plt.plot(samples.mean(axis=0))

# %%
d = 4
dd = 6
id = 0
chi = 2000
rootdir = '/project2/liangjiang/mliu6/DirectMPS/data_USTC_larger2/'
filename = rootdir + f"samples_d_{d}_dd_{dd}_chi_{chi}_{id}.npy"
samples = np.load(filename)
plt.plot(samples.mean(axis=0))

# %%
acc = []
for i in range(143):
    Lambda = np.load(rootdir + f'd_{d}_chi_{chi}/Lambda_{i}.npy')
    acc.append(np.sum(np.abs(Lambda)**2))

print(np.min(acc))
# Out:
# 0.98378766
